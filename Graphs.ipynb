# %% [markdown]
# ## Corpus Le Monde

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from scipy.signal import detrend
total = pd.read_csv("lemonde1.csv")
neg= pd.read_csv("neg_lemonde.csv")
pos= pd.read_csv("pos_lemonde.csv")

total = total.groupby("annee").sum().reset_index()[["annee","n"]]
total["Année"] = total.annee
total["Negativity"] = neg.n/total.n
total["Positivity"] = pos.n/total.n
total["Emotionality"] = total.Negativity + total.Positivity


px.scatter(total,x="Année",y=["Negativity","Positivity"],template="simple_white",trendline="lowess", trendline_options=dict(frac=0.4))
# Out:
# <div>                            <div id="7978d32f-60e3-4973-be7c-e6c6fed6467b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7978d32f-60e3-4973-be7c-e6c6fed6467b")) {                    Plotly.newPlot(                        "7978d32f-60e3-4973-be7c-e6c6fed6467b",                        [{"hovertemplate":"variable=Negativity<br>Année=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Negativity","marker":{"color":"#1F77B4","symbol":"circle"},"mode":"markers","name":"Negativity","orientation":"v","showlegend":true,"x":[1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,199
# ...

# %%
px.scatter(total,x="Année",y="Emotionality", trendline="lowess",template="simple_white", trendline_options=dict(frac=0.2))
# Out:
# <div>                            <div id="87efbf33-13e7-4d7b-84ac-46f465aac381" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("87efbf33-13e7-4d7b-84ac-46f465aac381")) {                    Plotly.newPlot(                        "87efbf33-13e7-4d7b-84ac-46f465aac381",                        [{"hovertemplate":"Année=%{x}<br>Emotionality=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#1F77B4","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,199
# ...

# %%
total["Negativity ratio"] = total.Negativity/total.Positivity

px.scatter(total,x="Année",y="Negativity ratio", trendline="lowess",template="simple_white", trendline_options=dict(frac=0.2))
# Out:
# <div>                            <div id="08f4d6ae-cc90-4f3d-a745-11ea15ea198a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("08f4d6ae-cc90-4f3d-a745-11ea15ea198a")) {                    Plotly.newPlot(                        "08f4d6ae-cc90-4f3d-a745-11ea15ea198a",                        [{"hovertemplate":"Année=%{x}<br>Negativity ratio=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#1F77B4","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996
# ...

# %% [markdown]
# ## Corpus Livres Gallica

# %%
total = pd.read_csv("base_livres_gallica_monogrammes.csv").sort_values("date").reset_index()
neg= pd.read_csv("neg_livres.csv")
pos= pd.read_csv("pos_livres.csv")


total['Année'] = total.date
total["Negativity"] = neg.n/total.base
total["Positivity"] = pos.n/total.base
total["Emotionality"] = total.Negativity + total.Positivity

total = total.loc[np.logical_and(total.date<1941,total.date>1599),:]

px.scatter(total,x="Année",y=["Negativity","Positivity"],template="simple_white",trendline="lowess", trendline_options=dict(frac=0.3))
# Out:
# <div>                            <div id="3d5aff7b-e29b-4e05-9799-141bdd652249" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d5aff7b-e29b-4e05-9799-141bdd652249")) {                    Plotly.newPlot(                        "3d5aff7b-e29b-4e05-9799-141bdd652249",                        [{"hovertemplate":"variable=Negativity<br>Année=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Negativity","marker":{"color":"#1F77B4","symbol":"circle"},"mode":"markers","name":"Negativity","orientation":"v","showlegend":true,"x":[1600,1601,1602,1603,1604,1605,1606,1607,1608,1609,1610,1611,1612,1613,1614,1615,1616,1617,1618,1619,1620,1621,1622,1623,1624,1625,1626,1627,1628,1629,1630,1631,1632,1633,1634,1635,1636,1637,1638,1639,1640,1641,1642,1643,1644,1645,164
# ...

# %%
px.scatter(total,x="date",y="Emotionality", trendline="lowess",template="simple_white", trendline_options=dict(frac=0.2))
# Out:
# <div>                            <div id="f500d8a0-38a5-44cb-b3bc-0c1baca27975" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f500d8a0-38a5-44cb-b3bc-0c1baca27975")) {                    Plotly.newPlot(                        "f500d8a0-38a5-44cb-b3bc-0c1baca27975",                        [{"hovertemplate":"date=%{x}<br>Emotionality=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#1F77B4","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[1600,1601,1602,1603,1604,1605,1606,1607,1608,1609,1610,1611,1612,1613,1614,1615,1616,1617,1618,1619,1620,1621,1622,1623,1624,1625,1626,1627,1628,1629,1630,1631,1632,1633,1634,1635,1636,1637,1638,1639,1640,1641,1642,1643,1644,1645,1646,1647,1648,1649,1650,1651,1652,1653
# ...

# %%
total["Negativity ratio"] = total.Negativity/total.Positivity

px.scatter(total,x="date",y="Negativity ratio", trendline="lowess",template="simple_white", trendline_options=dict(frac=0.2))
# Out:
# <div>                            <div id="febae648-fd8c-4d2b-b937-92a0e364d2d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("febae648-fd8c-4d2b-b937-92a0e364d2d2")) {                    Plotly.newPlot(                        "febae648-fd8c-4d2b-b937-92a0e364d2d2",                        [{"hovertemplate":"date=%{x}<br>Negativity ratio=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#1F77B4","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[1600,1601,1602,1603,1604,1605,1606,1607,1608,1609,1610,1611,1612,1613,1614,1615,1616,1617,1618,1619,1620,1621,1622,1623,1624,1625,1626,1627,1628,1629,1630,1631,1632,1633,1634,1635,1636,1637,1638,1639,1640,1641,1642,1643,1644,1645,1646,1647,1648,1649,1650,1651,1652,
# ...

# %% [markdown]
# ## Corpus presse

# %%
total = pd.read_csv("base_presse_mois_gallica_monogrammes.csv").sort_values("date").reset_index()
total[["Année","mois"]] = total.date.str.split("/",expand=True)
total = total.groupby("Année").sum().reset_index()
neg= pd.read_csv("neg_presse.csv")
pos= pd.read_csv("pos_presse.csv")
total.Année = total.Année.astype("int")


total["Negativity"] = neg.n/total.base
total["Positivity"] = pos.n/total.base
total["Negativity_ratio"] = total.Negativity/total.Positivity
total["Emotionality"] = total.Negativity + total.Positivity
total = total.loc[np.logical_and(total.Année<1951,total.Année>1788),:]
px.scatter(total,x="Année",y=["Negativity","Positivity"],template="simple_white",trendline="lowess", trendline_options=dict(frac=0.3))
# Out:
# <div>                            <div id="786e1496-f4f8-4841-942b-9ccef857435f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("786e1496-f4f8-4841-942b-9ccef857435f")) {                    Plotly.newPlot(                        "786e1496-f4f8-4841-942b-9ccef857435f",                        [{"hovertemplate":"variable=Negativity<br>Année=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Negativity","marker":{"color":"#1F77B4","symbol":"circle"},"mode":"markers","name":"Negativity","orientation":"v","showlegend":true,"x":[1789,1790,1791,1792,1793,1794,1795,1796,1797,1798,1799,1800,1801,1802,1803,1804,1805,1806,1807,1808,1809,1810,1811,1812,1813,1814,1815,1816,1817,1818,1819,1820,1821,1822,1823,1824,1825,1826,1827,1828,1829,1830,1831,1832,1833,1834,183
# ...

# %%
px.scatter(total,x="Année",y="Emotionality", trendline="lowess",template="simple_white", trendline_options=dict(frac=0.3))
# Out:
# <div>                            <div id="3cf0fdff-4477-4ac2-a926-993858d9df14" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3cf0fdff-4477-4ac2-a926-993858d9df14")) {                    Plotly.newPlot(                        "3cf0fdff-4477-4ac2-a926-993858d9df14",                        [{"hovertemplate":"Année=%{x}<br>Emotionality=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#1F77B4","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[1789,1790,1791,1792,1793,1794,1795,1796,1797,1798,1799,1800,1801,1802,1803,1804,1805,1806,1807,1808,1809,1810,1811,1812,1813,1814,1815,1816,1817,1818,1819,1820,1821,1822,1823,1824,1825,1826,1827,1828,1829,1830,1831,1832,1833,1834,1835,1836,1837,1838,1839,1840,1841,184
# ...

# %%
px.scatter(total,x="Année",y="Negativity_ratio", trendline="lowess",template="simple_white", trendline_options=dict(frac=0.2))
# Out:
# <div>                            <div id="afe20fd4-0f70-4fda-8a42-568dc96cb5ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("afe20fd4-0f70-4fda-8a42-568dc96cb5ff")) {                    Plotly.newPlot(                        "afe20fd4-0f70-4fda-8a42-568dc96cb5ff",                        [{"hovertemplate":"Année=%{x}<br>Negativity_ratio=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#1F77B4","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[1789,1790,1791,1792,1793,1794,1795,1796,1797,1798,1799,1800,1801,1802,1803,1804,1805,1806,1807,1808,1809,1810,1811,1812,1813,1814,1815,1816,1817,1818,1819,1820,1821,1822,1823,1824,1825,1826,1827,1828,1829,1830,1831,1832,1833,1834,1835,1836,1837,1838,1839,1840,1841
# ...
